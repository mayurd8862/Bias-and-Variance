# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/USA_Housing.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\mayur dabade\Desktop\3rd year\Statistical Inference\HA\Bias and Variance\main.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mayur%20dabade/Desktop/3rd%20year/Statistical%20Inference/HA/Bias%20and%20Variance/main.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('dataset/USA_Housing.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/mayur%20dabade/Desktop/3rd%20year/Statistical%20Inference/HA/Bias%20and%20Variance/main.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df.head()
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a synthetic dataset
np.random.seed(0)
X = np.sort(5 * np.random.rand(80, 1), axis=0)
y = np.sin(X).ravel() + np.random.normal(0, 0.1, 80)

# Create a feature matrix with polynomial features
X_poly = np.column_stack((X, X**2))

# Fit a linear regression model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_poly, y)

# Generate predictions
X_test = np.linspace(0, 5, 100)[:, np.newaxis]
X_test_poly = np.column_stack((X_test, X_test**2))
y_pred = lr.predict(X_test_poly)

# Plot the data and the overfit model
plt.scatter(X, y, color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)
plt.title("Overfit Linear Regression")
plt.show()

# %%
from sklearn.linear_model import Ridge

# Fit a Ridge regression model with regularization
ridge = Ridge(alpha=1.0)  # Adjust the alpha parameter for more or less regularization
ridge.fit(X_poly, y)

# Generate predictions
y_pred_ridge = ridge.predict(X_test_poly)

# Plot the data and the Ridge regression model
plt.scatter(X, y, color='black')
plt.plot(X_test, y_pred_ridge, color='red', linewidth=3)
plt.title("Ridge Regression with Regularization")
plt.show()
