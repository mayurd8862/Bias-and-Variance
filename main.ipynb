# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset/Delhi_properties.csv')
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# Generate sample data
np.random.seed(0)
X = np.random.rand(100, 1)
y = 2 * X + 1 + 0.1 * np.random.randn(100, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Fit a simple linear regression model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Predict on the test set
y_pred_lr = lr_model.predict(X_test)

# Fit a polynomial regression model (overfitting)
poly_features = PolynomialFeatures(degree=10)
X_train_poly = poly_features.fit_transform(X_train)
poly_model = LinearRegression()
poly_model.fit(X_train_poly, y_train)

X_test_poly = poly_features.transform(X_test)
y_pred_poly = poly_model.predict(X_test_poly)

# Plot the data and regression models
plt.scatter(X, y, label='Data', c='b')
plt.plot(X_test, y_pred_lr, label='Linear Regression', c='g')
plt.plot(X_test, y_pred_poly, label='Polynomial Regression (Overfit)', c='r')
plt.legend()
plt.xlabel('X')
plt.ylabel('y')
plt.title('Bias-Variance Trade-off')
plt.show()

# Calculate and print Mean Squared Error
mse_lr = mean_squared_error(y_test, y_pred_lr)
mse_poly = mean_squared_error(y_test, y_pred_poly)
print(f"Mean Squared Error (Linear Regression): {mse_lr:.3f}")
print(f"Mean Squared Error (Polynomial Regression): {mse_poly:.3f}")
# Out:
# Mean Squared Error (Linear Regression): 0.012
# Mean Squared Error (Polynomial Regression): 0.014
